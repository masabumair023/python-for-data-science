# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.arange(0,10)
y = np.arange(11,21)

# %% [markdown]
# # Scatter Plot

# %%
# Scatter Plot
plt.scatter(x,y, c='b')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('2D Graph')
plt.savefig('Test.png')

# %%
y = x*x

# %%
plt.plot(x,y, 'r*',linestyle='dashed', linewidth=2, markersize=12)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('2D Diagram')
# Out:
# Text(0.5, 1.0, '2D Diagram')

# %% [markdown]
# # SubPlot

# %%
 # SubPlot
plt.subplot(2,2,2)
plt.plot(x,y,'r--')
plt.subplot(2,2,1)
plt.plot(x,y,'b*-')
plt.subplot(2,2,4)
plt.plot(x,y,'black')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# sin curve
x = np.arange(0, 4*np.pi, 0.1)
y = np.sin(x)
plt.plot(x,y,'r')
plt.title('Sin Wave form')
# Out:
# Text(0.5, 1.0, 'Sin Wave form')

# %%
x = np.arange(0, 4*np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)


plt.subplot(2,1,1)
plt.plot(x, y_sin,'r--')
plt.title('Sin wave')


plt.subplot(2,1,2)
plt.plot(x, y_cos,'g*-')
plt.title('Cos wave')
# Out:
# Text(0.5, 1.0, 'Cos wave')

# %% [markdown]
# # Bar Graphs

# %%
#Bar Graphs
x1 = [2,8,10]
y1 = [11,16,9]

x2 = [3,9,11]
y2 = [6,15,7]

plt.bar(x1,y1)
plt.bar(x2,y2, color = 'g')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Bar Graph')
# Out:
# Text(0.5, 1.0, 'Bar Graph')

# %% [markdown]
# # Histogram

# %%
a = np.array([22,15,22,16,78,34,56,90,12,45,34,21,65,34,21,78,98,78,98])
plt.hist(a, bins = 20)
plt.title("Histogram");

# %% [markdown]
# # Box Plot

# %%
data = [np.random.normal(0, std, 100) for std in range(1,4)]

plt.boxplot(data, vert = True, patch_artist = True);

# %% [markdown]
# # Pie Chart

# %%
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0) #explode 1st slice

plt.pie(sizes, explode = explode, labels = labels, colors = colors, autopct = '%1.1f%%', shadow=True)
plt.axis('equal')
plt.show()
